# %% [markdown]
# ## Data Science project
#
# This file is the starting point of our program, it uses the other files and functions we've defined throughout the project and will be illusrating our results.

# %%
#libs and files

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scripts.center_points as center_points
import scripts.stats_data as stats_data
import scripts.class_imbalance as class_imbalance
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# CONSTANTES (DON'T CHANGE IT)
FACE_DIR    = r"CK+_lands/CK+/"
FACE_FILE   = "omlands.csv"
EMOTIONS_FILE   = r"CK+_lands/CK+/emotion.csv"
EMOTIONS_INDEX  = ["happy", "fear", "surprise", 
                   "anger", "disgust", "sadness"]

emotions = pd.read_csv(EMOTIONS_FILE, delimiter=";", header=0)

# %% [markdown]
# ## Exploratory Analysis

# %%
stats_data.get_number_of_instances()
# Out:
# {'anger': 36,
#  'disgust': 38,
#  'fear': 53,
#  'happy': 94,
#  'sadness': 59,
#  'surprise': 77}

# %%
stats_data.get_number_of_lines_per_emotions()
# Out:
# 100%|██████████| 124/124 [00:01<00:00, 66.13it/s]
# {'anger': 775,
#  'disgust': 602,
#  'fear': 872,
#  'happy': 1879,
#  'sadness': 1089,
#  'surprise': 1303}

# %%
face_points_centered = stats_data.get_difference_between_base_and_apex_from_file(FACE_DIR, "S005", FACE_FILE)
# Out:
# [ 430  400  429  478  439  555  457  631  486  701  537  764  601  812
#   670  852  748  864  823  849  890  811  952  764 1001  704 1028  635
#  1040  558 1044  481 1042  405  499  361  538  323  593  311  651  322
#   704  345  783  343  837  322  894  310  949  320  987  356  746  396
#   747  446  747  495  748  546  689  584  718  594  748  602  778  594
#   804  585  562  399  597  379  637  382  671  410  634  415  594  414
#   818  410  852  381  892  379  926  400  897  414  857  416  646  677
#   684  649  719  635  747  644  777  636  813  651  847  678  813  706
#   779  717  747  721  716  717  682  704  665  675  718  669  747  673
#   778  669  829  676  776  672  746  676  717  672]
